# %% [markdown]
# <a href="https://colab.research.google.com/github/jjukah/jjukah/blob/main/myFirstAIModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import torch

data = pd.read_csv("")

# %% [markdown]
# -import libraries (initialize objects)
# -get data
# -clean data (modify the table lines)
# -
